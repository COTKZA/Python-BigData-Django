# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
#%matplotlib inline 
#pip install openpyxl

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  classification
# 0             5.4          3.7           1.5          0.2     Iris-setosa
# 1             4.8          3.4           1.6          0.2     Iris-setosa
# 2             4.8          3.0           1.4          0.1     Iris-setosa
# 3             4.3          3.0           1.1          0.1     Iris-setosa
# 4             5.8          4.0           1.2          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# การดูข้อมูลคอลัมน์ classification
d = df['classification'].unique()
d
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# การนำดอกไอริสมาฝึกสอน AI ให้เรียนรู้และจดจำ เพื่อจำแนกประเภท ดังนี้
# 1) sepal_length = ความยาวของกลีบเลี้ยง
# 2) sepal_width = ความกว้างของกลีบเลี้ยง
# 3) petal_length = ความยาวของกลีบดอก
# 4) petal_width = ความกว้างของกลีบดอก
# 5) classification = ประเภทสายพันธุ์ดอกไอริส ได้แก่ สายพันธุ์ Iris-setosa, Iris-versicolor, Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sepal_length    150 non-null    float64
#  1   sepal_width     150 non-null    float64
#  2   petal_length    150 non-null    float64
#  3   petal_width     150 non-null    float64
#  4   classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
X = df.iloc[:,:-1] #.values 
y = df.iloc[:,-1] #.values

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.4          3.7           1.5          0.2
# 1             4.8          3.4           1.6          0.2
# 2             4.8          3.0           1.4          0.1
# 3             4.3          3.0           1.1          0.1
# 4             5.8          4.0           1.2          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: classification, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) #, random_state=48)

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 117           7.7          3.8           6.7          2.2
# 10            5.1          3.5           1.4          0.2
# 146           6.3          2.5           5.0          1.9
# 22            4.6          3.6           1.0          0.2
# 111           6.4          2.7           5.3          1.9
# 78            6.0          2.9           4.5          1.5
# 119           6.0          2.2           5.0          1.5
# 144           6.7          3.3           5.7          2.5
# 62            6.0          2.2           4.0          1.0
# 73            6.1          2.8           4.7          1.2
# 72            6.3          2.5           4.9          1.5
# 134           6.1          2.6           5.6          1.4
# 61            5.9          3.0           4.2          1.5
# 74            6.4          2.9           4.3          1.3
# 51            6.4          3.2           4.5          1.5
# 102           7.1          3.0           5.9          2.1
# 122           7.7          2.8           6.7          2.0
# 98            5.1          2.5           3.0          1.1
# 143           6.8          3.2           5.9          2.3
# 57            4.9          2.4           3.3          1.0
# 132           6.4          2.8           5.6          2.2
# 142           5.8          2.7           5.1          1.9
# 139           6.9          3.1           5.4          2.1
# 46            5.1          3.8           1.6          0.2
# 1             4.8          3.4           1.6          0.2
# 123           6.3          2.7           4.9          1.8
# 105           7.6          3.0           6.6          2.1
# 89            5.5          2.5           4.0          1.3
# 116           6.5          3.0           5.5          1.8
# 85            6.0          3.4           4.5          1.6
# 107           7.3          2.9           6.3          1.8
# 115           6.4          3.2           5.3          2.3
# 6             5.4          3.9           1.3          0.4
# 52            6.9          3.1           4.9          1.5
# 108           6.7          2.5           5.8          1.8
# 0             5.4          3.7           1.5          0.2
# 2             4.8          3.0           1.4          0.1
# 110           6.5          3.2           5.1          2.0
# 56            6.3          3.3           4.7          1.6
# 140           6.7          3.1           5.6          2.4
# 113           5.7          2.5           5.0          2.0
# 80            5.5          2.4           3.8          1.1
# 19            4.9          3.1           1.5          0.1
# 25            5.0          3.0           1.6          0.2
# 101           5.8          2.7           5.1          1.9

# %%
from sklearn.svm import SVC
#model = SVC(kernel='linear')
#model = SVC(kernel='linear', probability=True)
#model = SVC(kernel='poly', degree=3, gamma='auto')
model = SVC(gamma='auto')
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
y_predict.reshape(-1, 1)
# Out:
# array([['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-virginica']], dtype=object)

# %% [markdown]
# ### การบันทึกโมเดล เพื่อนำไปใช้งาน หรือนำไปพัฒนาด้วยระบบ Python Django

# %% [markdown]
# ##### วิธีที่ 1

# %%
#https://www.youtube.com/watch?v=rNhVBv0i4os
# วิธีที่ 1

# from joblib import dump

# dump(model, 'model.joblib')
# Out:
# ['model.joblib']

# %% [markdown]
# ##### วิธีที่ 2

# %%
# # วิธีที่ 2
# from pandas import read_csv

# #Pickle model 
# pd.to_pickle(model, 'model.pickle')

# #Unpickle model 
# model = pd.read_pickle('model.pickle')

# %% [markdown]
# ##### วิธีที่ 3

# %%
#conda install -c anaconda scikit-learn
#pip install -U scikit-learn
from sklearn.externals import joblib
import numpy as np
import joblib

joblib.dump(model, 'model.pkl')
model = joblib.load('model.pkl')

# %% [markdown]
# ##### การนำโมเดลไปพยากรณ์

# %%
#Take input from user 
sepal_length = float(input("Enter sepal_length: "))
sepal_width = float(input("Enter sepal_width: "))
petal_length = float(input("Enter petal_length: "))
petal_width = float(input("Enter petal_width: "))

# %%
result = model.predict([[sepal_length, sepal_width, petal_length, petal_width]])
print(result)
# Out:
# ['Iris-virginica']
# c:\Users\Taechatuch\anaconda3\envs\mydata\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
#การป้อนข้อมูลพยากรณ์
pred1 = [[5.1,3.5,1.4,0.2],
         [5.9,3.0,5.1,1.8]]
         
df = model.predict(pred1)

i = 1
for m in range(len(df)):
    print('%d' %i, df[m])
    i += 1
# Out:
# 1 Iris-setosa
# 2 Iris-virginica
# c:\Users\Taechatuch\anaconda3\envs\mydata\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
ypred = pd.DataFrame(y_predict)
data = ypred.rename(columns={0:'ข้อมูลพยากรณ์'})
data
# Out:
#       ข้อมูลพยากรณ์
# 0    Iris-virginica
# 1    Iris-virginica
# 2   Iris-versicolor
# 3       Iris-setosa
# 4    Iris-virginica
# 5    Iris-virginica
# 6    Iris-virginica
# 7   Iris-versicolor
# 8   Iris-versicolor
# 9    Iris-virginica
# 10      Iris-setosa
# 11   Iris-virginica
# 12      Iris-setosa
# 13      Iris-setosa
# 14  Iris-versicolor
# 15   Iris-virginica
# 16      Iris-setosa
# 17   Iris-virginica
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21  Iris-versicolor
# 22  Iris-versicolor
# 23   Iris-virginica
# 24  Iris-versicolor
# 25  Iris-versicolor
# 26      Iris-setosa
# 27      Iris-setosa
# 28  Iris-versicolor
# 29      Iris-setosa
# 30      Iris-setosa
# 31  Iris-versicolor
# 32      Iris-setosa
# 33  Iris-versicolor
# 34   Iris-virginica
# 35   Iris-virginica
# 36   Iris-virginica
# 37  Iris-versicolor
# 38  Iris-versicolor
# 39   Iris-virginica
# 40      Iris-setosa
# 41  Iris-versicolor
# 42   Iris-virginica
# 43  Iris-versicolor
# 44  Iris-versicolor

# %%
ytest = pd.DataFrame(y_test).reset_index()
data2 = ytest.rename(columns={'classification':'ข้อมูลจริง'})
dt = data2.drop(['index'], axis=1) #ลบคอลัมน์ index
dt
# Out:
#          ข้อมูลจริง
# 0   Iris-versicolor
# 1    Iris-virginica
# 2   Iris-versicolor
# 3       Iris-setosa
# 4    Iris-virginica
# 5    Iris-virginica
# 6    Iris-virginica
# 7   Iris-versicolor
# 8   Iris-versicolor
# 9    Iris-virginica
# 10      Iris-setosa
# 11   Iris-virginica
# 12      Iris-setosa
# 13      Iris-setosa
# 14  Iris-versicolor
# 15   Iris-virginica
# 16      Iris-setosa
# 17   Iris-virginica
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21  Iris-versicolor
# 22  Iris-versicolor
# 23   Iris-virginica
# 24  Iris-versicolor
# 25  Iris-versicolor
# 26      Iris-setosa
# 27      Iris-setosa
# 28  Iris-versicolor
# 29      Iris-setosa
# 30      Iris-setosa
# 31  Iris-versicolor
# 32      Iris-setosa
# 33  Iris-versicolor
# 34   Iris-virginica
# 35   Iris-virginica
# 36   Iris-virginica
# 37  Iris-versicolor
# 38  Iris-versicolor
# 39   Iris-virginica
# 40      Iris-setosa
# 41  Iris-versicolor
# 42   Iris-virginica
# 43  Iris-versicolor
# 44  Iris-versicolor

# %%
#ตารางเปรียบเทียบข้อมูลจริงและการพยากรณ์
#total.to_csv('data.csv')
#total.to_excel('data.xlsx')

total = pd.concat([dt,data],axis=1) #.round(0)
total
# Out:
#          ข้อมูลจริง    ข้อมูลพยากรณ์
# 0   Iris-versicolor   Iris-virginica
# 1    Iris-virginica   Iris-virginica
# 2   Iris-versicolor  Iris-versicolor
# 3       Iris-setosa      Iris-setosa
# 4    Iris-virginica   Iris-virginica
# 5    Iris-virginica   Iris-virginica
# 6    Iris-virginica   Iris-virginica
# 7   Iris-versicolor  Iris-versicolor
# 8   Iris-versicolor  Iris-versicolor
# 9    Iris-virginica   Iris-virginica
# 10      Iris-setosa      Iris-setosa
# 11   Iris-virginica   Iris-virginica
# 12      Iris-setosa      Iris-setosa
# 13      Iris-setosa      Iris-setosa
# 14  Iris-versicolor  Iris-versicolor
# 15   Iris-virginica   Iris-virginica
# 16      Iris-setosa      Iris-setosa
# 17   Iris-virginica   Iris-virginica
# 18      Iris-setosa      Iris-setosa
# 19      Iris-setosa      Iris-setosa
# 20      Iris-setosa      Iris-setosa
# 21  Iris-versicolor  Iris-versicolor
# 22  Iris-versicolor  Iris-versicolor
# 23   Iris-virginica   Iris-virginica
# 24  Iris-versicolor  Iris-versicolor
# 25  Iris-versicolor  Iris-versicolor
# 26      Iris-setosa      Iris-setosa
# 27      Iris-setosa      Iris-setosa
# 28  Iris-versicolor  Iris-versicolor
# 29      Iris-setosa      Iris-setosa
# 30      Iris-setosa      Iris-setosa
# 31  Iris-versicolor  Iris-versicolor
# 32      Iris-setosa      Iris-setosa
# 33  Iris-versicolor  Iris-versicolor
# 34   Iris-virginica   Iris-virginica
# 35   Iris-virginica   Iris-virginica
# 36   Iris-virginica   Iris-virginica
# 37  Iris-versicolor  Iris-versicolor
# 38  Iris-versicolor  Iris-versicolor
# 39   Iris-virginica   Iris-virginica
# 40      Iris-setosa      Iris-setosa
# 41  Iris-versicolor  Iris-versicolor
# 42   Iris-virginica   Iris-virginica
# 43  Iris-versicolor  Iris-versicolor
# 44  Iris-versicolor  Iris-versicolor

# %%
Xtest = X_test.reset_index()
ds = Xtest.drop(['index'], axis=1) #ลบคอลัมน์ index
sum = pd.concat([ds, total],axis=1) #.round(0)
sum
# Out:
#     sepal_length  sepal_width  petal_length  petal_width       ข้อมูลจริง  \
# 0            5.9          3.2           4.8          1.8  Iris-versicolor
# 1            6.8          3.2           5.9          2.3   Iris-virginica
# 2            6.0          2.2           4.0          1.0  Iris-versicolor
# 3            4.6          3.2           1.4          0.2      Iris-setosa
# 4            6.7          3.1           5.6          2.4   Iris-virginica
# 5            6.4          3.1           5.5          1.8   Iris-virginica
# 6            7.7          2.8           6.7          2.0   Iris-virginica
# 7            5.6          3.0           4.1          1.3  Iris-versicolor
# 8            5.5          2.3           4.0          1.3  Iris-versicolor
# 9            7.2          3.6           6.1          2.5   Iris-virginica
# 10           5.2          4.1           1.5          0.1      Iris-setosa
# 11           6.3          3.3           6.0          2.5   Iris-virginica
# 12           5.5          3.5           1.3          0.2      Iris-setosa
# 13           5.0          3.2           1.2          0.2      Iris-setosa
# 14           4.9          2.4           3.3          1.0  Iris-versicolor
# 15           7.7          2.6           6.9          2.3   Iris-virginica
# 16           5.0          3.5           1.3          0.3      Iris-setosa
# 17           6.9          3.2           5.7          2.3   Iris-virginica
# 18           5.2          3.4           1.4          0.2      Iris-setosa
# 19           4.3          3.0           1.1          0.1      Iris-setosa
# 20           4.9          3.1           1.5          0.1      Iris-setosa
# 21           5.6          2.9           3.6          1.3  Iris-versicolor
# 22           5.1          2.5           3.0          1.1  Iris-versicolor
# 23           7.6          3.0           6.6          2.1   Iris-virginica
# 24           7.0          3.2           4.7          1.4  Iris-versicolor
# 25           5.6          2.5           3.9          1.1  Iris-versicolor
# 26           5.1          3.8           1.5          0.3      Iris-setosa
# 27           4.8          3.1           1.6          0.2      Iris-setosa
# 28           6.7          3.1           4.7          1.5  Iris-versicolor
# 29           5.7          3.8           1.7          0.3      Iris-setosa
# 30           5.1          3.3           1.7          0.5      Iris-setosa
# 31           6.1          2.8           4.0          1.3  Iris-versicolor
# 32           4.9          3.0           1.4          0.2      Iris-setosa
# 33           5.7          3.0           4.2          1.2  Iris-versicolor
# 34           6.9          3.1           5.4          2.1   Iris-virginica
# 35           6.0          3.0           4.8          1.8   Iris-virginica
# 36           5.6          2.8           4.9          2.0   Iris-virginica
# 37           5.5          2.5           4.0          1.3  Iris-versicolor
# 38           6.0          3.4           4.5          1.6  Iris-versicolor
# 39           6.5          3.0           5.8          2.2   Iris-virginica
# 40           5.0          3.4           1.6          0.4      Iris-setosa
# 41           5.7          2.6           3.5          1.0  Iris-versicolor
# 42           6.4          2.8           5.6          2.1   Iris-virginica
# 43           5.8          2.6           4.0          1.2  Iris-versicolor
# 44           5.5          2.4           3.8          1.1  Iris-versicolor
#
#       ข้อมูลพยากรณ์
# 0    Iris-virginica
# 1    Iris-virginica
# 2   Iris-versicolor
# 3       Iris-setosa
# 4    Iris-virginica
# 5    Iris-virginica
# 6    Iris-virginica
# 7   Iris-versicolor
# 8   Iris-versicolor
# 9    Iris-virginica
# 10      Iris-setosa
# 11   Iris-virginica
# 12      Iris-setosa
# 13      Iris-setosa
# 14  Iris-versicolor
# 15   Iris-virginica
# 16      Iris-setosa
# 17   Iris-virginica
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21  Iris-versicolor
# 22  Iris-versicolor
# 23   Iris-virginica
# 24  Iris-versicolor
# 25  Iris-versicolor
# 26      Iris-setosa
# 27      Iris-setosa
# 28  Iris-versicolor
# 29      Iris-setosa
# 30      Iris-setosa
# 31  Iris-versicolor
# 32      Iris-setosa
# 33  Iris-versicolor
# 34   Iris-virginica
# 35   Iris-virginica
# 36   Iris-virginica
# 37  Iris-versicolor
# 38  Iris-versicolor
# 39   Iris-virginica
# 40      Iris-setosa
# 41  Iris-versicolor
# 42   Iris-virginica
# 43  Iris-versicolor
# 44  Iris-versicolor

# %% [markdown]
# #### การสร้างไดอะแกรม SVM

# %%
df = pd.read_csv('iris.csv')
#dt = df.drop(['Id'], axis=1) #ลบคอลัมน์ index
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  classification
# 0             5.4          3.7           1.5          0.2     Iris-setosa
# 1             4.8          3.4           1.6          0.2     Iris-setosa
# 2             4.8          3.0           1.4          0.1     Iris-setosa
# 3             4.3          3.0           1.1          0.1     Iris-setosa
# 4             5.8          4.0           1.2          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
class_names = df['classification'].unique()
class_names
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

print('Accuracy Score: {:.2f}'.format(accuracy_score(y_test, y_predict)))
#print('Accuracy Score:',accuracy_score(y_test, y_predict).round(2))
print(classification_report(y_test, y_predict, target_names=class_names))
cm = confusion_matrix(y_test, y_predict)
print(cm)

#pip install scikit-plot
import scikitplot as skplot
plt.rcParams['figure.figsize'] = 6,6 #10 x 10
skplot.metrics.plot_confusion_matrix(y_test, y_predict)
plt.show()
# Out:
# Accuracy Score: 0.98
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       1.00      0.94      0.97        17
#  Iris-virginica       0.93      1.00      0.97        14
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45
#
# [[14  0  0]
#  [ 0 16  1]
#  [ 0  0 14]]

# %% [markdown]
# ### การประเมินโมเดลแบบ cross_validation

# %%
# from sklearn.model_selection import cross_val_score

# cvs = cross_val_score(model, X, y, cv=10)
# print('cross_val_scores = {}'.format(cvs))
# print('mean = {:4f}'.format(cvs.mean()))
